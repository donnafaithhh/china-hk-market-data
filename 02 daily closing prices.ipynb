# %% [markdown]
# This notebook was created by Donna Faith Go.

# %%
import sys
# !{sys.executable} -m pip install -qq -r requirements.txt

# %%
# standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import os

# data gathering
import yfinance as yf
import time
import pandas_datareader.data as web
from datetime import datetime, timedelta

# ignore warnings
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ## Daily Closing Prices

# %% [markdown]
# ## Stock Tickers

# %%
filepath = 'SSE companies list.pkl'
with open(filepath, 'rb') as f:
    companies_df = pickle.load(f)
companies_df.head()
companies_df = companies_df[:600]

# %%
# add the suffix to make it compatible with yfinance
tickers_list = companies_df['Company Code'].to_list()
tickers_list = [ticker + ".SS" for ticker in tickers_list]

# check if it worked
print(tickers_list[:5])
# Out:
# ['600000.SS', '600004.SS', '600006.SS', '600007.SS', '600008.SS']

# %%
# sanity checks
print(tickers_list[0])
print(companies_df['Company Name'][0])
print(len(companies_df) == len(tickers_list)) # should be True
# Out:
# 600000.SS
# SHANGHAI PUDONG DEVELOPMENT BANK CO., LTD.
# True

# %% [markdown]
# ## yfinance

# %%
# pull individual stock data from yfinance
def download_info_per_stock(ticker, verbose=False, 
                            start_date='2000-01-01', 
                            end_date='2026-01-01'):
        try:
            # get data for the ticker
            ticker_data = yf.download(
                ticker,
                start=start_date,
                end=end_date,
                progress=False,
                timeout=120 # in case of slow internet, in seconds
            )
            return pd.DataFrame(ticker_data)
            
        except Exception as e:
            if verbose:
                print(f"Error downloading {ticker}.")
            return None

# saving individual stock data
def save_info_per_stock(ticker_list, delay=1, 
                        verbose=False, override=False,
                        start_date='2000-01-01', 
                        end_date='2026-01-01'):
    
    # create the data folder
    os.makedirs("data", exist_ok=True)

    for i in range(0, len(ticker_list)):
        # declare company name and filepath
        ticker_name = companies_df['Company Name'][i]
        filepath = f"data/{ticker_name}.pkl"

        # skip if not override and file exists
        if override == False and os.path.exists(filepath):
            if verbose:
                print(f"Skipped {ticker_name}.")
                continue
        else:                    
            # get the data for each stock
            if verbose:
                print()
                print(f"Downloading for ticker: {ticker_list[i]}")
            ticker_data = download_info_per_stock(ticker_list[i],
                                                  start_date=start_date,
                                                  end_date=end_date)
    
            # saving data as a pkl file
            if ticker_data is not None and not ticker_data.empty:
                ticker_data.to_pickle(filepath)
                if verbose == True:
                    print(f"Saved data for {ticker_name}.")
            
            # avoid rate limiting
            time.sleep(delay)

    print("Done downloading all data!")

# %%
save_info_per_stock(tickers_list, verbose=True)
# Out:
# Skipped SHANGHAI PUDONG DEVELOPMENT BANK CO., LTD..
# Skipped Guangzhou Baiyun International Airport Co.,ltd..
# Skipped Dongfeng  Automobile  Co.,LTD.
# Skipped China World Trade Center Company Ltd..
# Skipped Beijing Capital Eco-Environment Protection Group Co.,Ltd..
# Skipped Shanghai International Airport Co., Ltd..
# Skipped Inner Mongolia BaoTou Steel Union Co.,Ltd..
# Skipped Huaneng Power International, INC..
# Skipped Anhui Expressway Company Limited.
# Skipped HUA XIA BANK CO., Limited.
# Skipped CHINA MINSHENG BANK.
# Skipped RIZHAO PORT CO.,LTD..
# Saved data for JIANGXI HONGCHENG ENVIRONMENT CO., LTD..
#
# Downloading for ticker: 600463.SS
# Saved data for Beijing Airport High-Tech Park Co.,Ltd..
#
# Downloading for ticker: 600467.SS
# Saved data for SHANDONG  HOMEY  AQUATIC  DEVELOPMENT  CO.,LTD..
#
# Downloading for ticker: 600468.SS
# Saved data for TIANJIN BENEFO TEJING ELECTRIC CO.,LTD..
#
# Downloading for ticker: 600469.SS
# Saved data for AEOLUS TYRE CO.,LTD.
#
# Downloading for ticker: 600470.SS
# Saved data for Anhui Liuguo Chemical Co.,Ltd..
#
# Downloading for ticker: 600475.SS
# Saved data for Wuxi Huaguang Environment & Energy Group Co.,Ltd..
#
# Downloading for ticker: 600476.SS
# Saved data for Hunan  Copote  Science&Technology  Co.,Ltd..
#
# Downloading for ticker: 600477.SS
# Saved data for HANGXIAO STEEL STRUCTURE CO.,LTD.
#
# Downloading for ticker: 600478.SS
# Saved data for HUNAN  CORUN  NEW  ENERGY  CO.，LTD..
#
# Downloading for ticker: 600479.SS
# Saved data for ZhuZhou QianJin Pharmaceutical Co., Ltd..
#
# Downloading for ticker: 600480.SS
# Saved data for LINGYUN  INDUSTRIAL  CORPORATION  LIMITED.
#
# Downloading for ticker: 600481.SS
# Saved data for Shuangliang Eco-Energy Systems Co.,Ltd.
#
# Downloading for ticker: 600482.SS
# Saved data for China Shipbuilding Industry Group Power Co., Ltd..
#
# Downloading for ticker: 600483.SS
# Saved data for FUJIAN FUNENG CO.，LTD..
#
# Downloading for ticker: 600486.SS
# Saved data for Jiangsu Yangnong Chemical Co.,Ltd..
#
# Downloading for ticker: 600487.SS
# Saved data for Hengtong Optic-Electric Co.,Ltd..
#
# Downloading for ticker: 600488.SS
# Saved data for Tianjin Tianyao Pharmaceutical Co., Ltd..
#
# Downloading for ticker: 600489.SS
# Saved data for ZHONGJIN GOLD CORPORATION LIMITED.
#
# Downloading for ticker: 600490.SS
# Saved data for Pengxin International Mining Co.,Ltd.
#
# Downloading for ticker: 600491.SS
# Saved data for LONG YUAN CONSTRUCTION GUOUP CO.,LTD.
#
# Downloading for ticker: 600493.SS
# Saved data for fujian fynex textile science & technology co.，ltd..
#
# Downloading for ticker: 600495.SS
# Saved data for JINXI AXLE COMPANY LIMITED.
#
# Downloading for ticker: 600496.SS
# Saved data for changjiang & jinggong steel building (group) co.,ltd.
#
# Downloading for ticker: 600497.SS
# Saved data for Yunnan Chihong Zinc&Germanium Co.,Ltd..
#
# Downloading for ticker: 600498.SS
# Saved data for Fiberhome Telecommunication Technologies Co.,Ltd..
#
# Downloading for ticker: 600499.SS
# Saved data for Keda Industrial Group Co., Ltd..
#
# Downloading for ticker: 600500.SS
# Saved data for SINOCHEM INTERNATIONAL CORPORATION.
#
# Downloading for ticker: 600501.SS
# Saved data for Aerosun Corporation.
#
# Downloading for ticker: 600502.SS
# Saved data for Anhui Construction Engineering Group Corporation Limited.
#
# Downloading for ticker: 600503.SS
# Saved data for Deluxe Family Co., Ltd..
#
# Downloading for ticker: 600505.SS
# Saved data for Sichuan Xichang Electric Power Co.,Ltd.
#
# Downloading for ticker: 600506.SS
# Saved data for Tongyi Carbon Neutral Technology (Xinjiang) Co., Ltd..
#
# Downloading for ticker: 600507.SS
# Saved data for FANGDA SPECIAL STEEL TECHNOLOGY CO., LTD.
#
# Downloading for ticker: 600508.SS
# Saved data for SHANGHAI DATUN ENERGY RESOURSES CO.,LTD..
#
# Downloading for ticker: 600509.SS
# Saved data for XINJIANG TIANFU ENERGY CO.,LTD.
#
# Downloading for ticker: 600510.SS
# Saved data for BLACK PEONY (GROUP) CO., LTD..
#
# Downloading for ticker: 600511.SS
# Saved data for China National Medicines Corporation Ltd..
#
# Downloading for ticker: 600512.SS
# Saved data for Tengda Construction Group Co.,Ltd..
#
# Downloading for ticker: 600513.SS
# Saved data for Jiangsu Lianhuan Pharmaceutical Co., Ltd..
#
# Downloading for ticker: 600515.SS
# Saved data for Hainan Airport Infrastructure Co., Ltd.
#
# Downloading for ticker: 600516.SS
# Saved data for FangDa Carbon New Material CO.,LTD.
#
# Downloading for ticker: 600517.SS
# Saved data for State Grid Yingda Co.,ltd..
#
# Downloading for ticker: 600518.SS
# Saved data for Kangmei Pharmaceutical Co., Ltd.
#
# Downloading for ticker: 600519.SS
# Saved data for KWEICHOW MOUTAI CO.,LTD..
#
# Downloading for ticker: 600520.SS
# Saved data for HIIG Trinity (Anhui) Technology Co., LTD..
#
# Downloading for ticker: 600521.SS
# Saved data for Zhejiang Huahai Pharmaceutical Co.,LTD..
#
# Downloading for ticker: 600522.SS
# Saved data for JIANGSU ZHONGTIAN TECHNOLOGY CO.,LTD..
#
# Downloading for ticker: 600523.SS
# Saved data for GUIZHOU GUIHANG AOTOMOTIVE COMPONENTS CO., LTD.
#
# Downloading for ticker: 600526.SS
# Saved data for ZHEJIANG FEIDA ENVIRONMENTAL SCIENCE &TECHNOLOGY CO.,LTD..
#
# Downloading for ticker: 600527.SS
# Saved data for Jiangsu Jiangnan High Polymer Fiber CO.,Ltd.
#
# Downloading for ticker: 600528.SS
# Saved data for China Railway Hi-tech Industry Corporation Limited.
#
# Downloading for ticker: 600529.SS
# Saved data for SHANDONG PHARMACEUTICAL GLASS CO.,LTD.
#
# Downloading for ticker: 600530.SS
# Saved data for SHANGHAI JIAODA ONLLY CO.,LTD.
#
# Downloading for ticker: 600531.SS
# Saved data for HENAN YUGUANG GOLD&LEAD CO.，LTD.
#
# Downloading for ticker: 600533.SS
# Saved data for NANJING CHIXIA DEVELOPMENT CO., LTD..
#
# Downloading for ticker: 600535.SS
# Saved data for Tasly Pharmaceutical Group CO., LTD..
#
# Downloading for ticker: 600536.SS
# Saved data for CHINA NATIONAL SOFTWARE & SERVICE COMPANY LIMITED.
#
# Downloading for ticker: 600537.SS
# Saved data for EGing Photovoltaic Technology Co., Ltd..
#
# Downloading for ticker: 600538.SS
# Saved data for Beihai Gofar Chuanshan Biological Co., Ltd..
#
# Downloading for ticker: 600539.SS
# Saved data for Lionhead Technology Development Co.,Ltd..
#
# Downloading for ticker: 600540.SS
# Saved data for XINJIANG SAYRAM MODERN AGRICULTURE CO.,LTD..
#
# Downloading for ticker: 600543.SS
# Saved data for GANSU MOGAO INDUSTRIAL DEVELOPMENT CO.,LTD..
#
# Downloading for ticker: 600545.SS
# Saved data for SAURER INTELLIGENT TECHNOLOGY CO., LTD..
#
# Downloading for ticker: 600546.SS
# Saved data for Shanxi Coal International Energy Group Co.,LTD.
#
# Downloading for ticker: 600547.SS
# Saved data for SHANDONG GOLD MINING CO.,LTD..
#
# Downloading for ticker: 600548.SS
# Saved data for Shenzhen Expressway Corporation Limited.
#
# Downloading for ticker: 600549.SS
# Saved data for XIAMEN TUNGSTEN CORP..
#
# Downloading for ticker: 600550.SS
# Saved data for BAODING TIANWEI BAOBIAN ELECTRIC CO.,LTD.
#
# Downloading for ticker: 600551.SS
# Saved data for Time Publishing & Media CO., LTD..
#
# Downloading for ticker: 600552.SS
# Saved data for TRIUMPH SCIENCE & TECHNOLOGY CO., LTD.
#
# Downloading for ticker: 600556.SS
# Saved data for INMYSHOW DIGITAL TECHNOLOGY （GROUP） CO., LTD..
#
# Downloading for ticker: 600557.SS
# Saved data for Jiangsu Kanion Pharmaceutical Co.,Ltd..
#
# Downloading for ticker: 600558.SS
# Saved data for ATLANTIC CHINA WELDING CONSUMABLES,INC..
#
# Downloading for ticker: 600559.SS
# Saved data for HEBEI HENGSHUI LAOBAIGAN LIQUOR CO.，LTD..
#
# Downloading for ticker: 600560.SS
# Saved data for Beijing AriTime Intelligent Control Co., Ltd..
#
# Downloading for ticker: 600561.SS
# Saved data for Jiangxi Changyun Co., Ltd..
#
# Downloading for ticker: 600562.SS
# Saved data for GLARUN TECHNOLOGY CO．，LTD．.
#
# Downloading for ticker: 600563.SS
# Saved data for Xiamen Faratronic Co.,LTD..
#
# Downloading for ticker: 600566.SS
# Saved data for HUBEI JUMPCAN PHARMACEUTICAL CO., LTD..
#
# Downloading for ticker: 600567.SS
# 1 Failed download:
# ['600567.SS']: Timeout('Failed to perform, curl: (28) Operation timed out after 430884 milliseconds with 93650 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
#
# 1 Failed download:
# ['600569.SS']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 128 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600569.SS
# 1 Failed download:
# ['600570.SS']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 56 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600570.SS
#
# Downloading for ticker: 600571.SS
# Saved data for SUNYARD TECHNOLOGY CO.,LTD.
#
# Downloading for ticker: 600572.SS
# Saved data for ZHEJIANG CONBA PHARMACEUTICAL CO.,LTD..
#
# Downloading for ticker: 600573.SS
# Saved data for FuJian YanJing HuiQuan Brewery Co.,Ltd.
#
# Downloading for ticker: 600575.SS
# Saved data for Huaihe Energy (Group) Co.,Ltd.
#
# Downloading for ticker: 600576.SS
# Saved data for Zhejiang Sunriver Culture Tourism Co.,.
#
# Downloading for ticker: 600577.SS
# Saved data for TONGLING JINGDA SPECIAL MAGNET WIRE CO.,LTD..
#
# Downloading for ticker: 600578.SS
# Saved data for BEIJING JINGNENG POWER CO.,LTD..
#
# Downloading for ticker: 600579.SS
# Saved data for Sinochem Equipment Technology (Qingdao) Company Limited.
#
# Downloading for ticker: 600580.SS
# Saved data for WOLONG ELECTRIC GROUP CO.，LTD..
#
# Downloading for ticker: 600581.SS
# Saved data for XinJiang Ba Yi Iron & Steel Co., Ltd.
#
# Downloading for ticker: 600582.SS
# Saved data for Tiandi Science & Technology Co.,LTD.
#
# Downloading for ticker: 600583.SS
# Saved data for OFFSHORE OIL ENGINEERING CO., LTD..
#
# Downloading for ticker: 600584.SS
# Saved data for JCET  Group  Co., Ltd..
#
# Downloading for ticker: 600585.SS
# Saved data for Anhui Conch Cement Company Limited.
#
# Downloading for ticker: 600586.SS
# Saved data for Shandong Jinjing Science & Technology Co.,Ltd.
#
# Downloading for ticker: 600587.SS
# Saved data for Shinva Medical Instrument Co.,Ltd..
#
# Downloading for ticker: 600588.SS
# 1 Failed download:
# ['600588.SS']: ConnectionError('Failed to perform, curl: (56) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600589.SS
# 1 Failed download:
# ['600589.SS']: ConnectionError('Failed to perform, curl: (7) Failed to connect to query2.finance.yahoo.com port 443 after 37210 ms: Could not connect to server. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600590.SS
# 1 Failed download:
# ['600590.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600592.SS
# 1 Failed download:
# ['600592.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600593.SS
# 1 Failed download:
# ['600593.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600594.SS
# 1 Failed download:
# ['600594.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600595.SS
# 1 Failed download:
# ['600595.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600596.SS
# 1 Failed download:
# ['600596.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600597.SS
# 1 Failed download:
# ['600597.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600598.SS
# 1 Failed download:
# ['600598.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600600.SS
# 1 Failed download:
# ['600600.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600601.SS
# 1 Failed download:
# ['600601.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600602.SS
# 1 Failed download:
# ['600602.SS']: DNSError('Failed to perform, curl: (6) Could not resolve host: query2.finance.yahoo.com. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600603.SS
# Saved data for GUANGHUI LOGISTICS CO.，LTD.
#
# Downloading for ticker: 600604.SS
# Saved data for SHANGHAI SHIBEI HI-TECH CO.,LTD..
#
# Downloading for ticker: 600605.SS
# Saved data for SHANGHAI HUITONG ENERGY CO.,LTD..
#
# Downloading for ticker: 600606.SS
# Saved data for Greenland Holdings Corporation Limited.
#
# Downloading for ticker: 600609.SS
# Saved data for SHENYANG JINBEI AUTOMOTIVE COMPANY LIMTED.
#
# Downloading for ticker: 600610.SS
# Saved data for Guizhou Zhong Yi Da Co.,Ltd.
#
# Downloading for ticker: 600611.SS
# Saved data for DAZHONG TRANSPORTATION（GROUP）CO.,LTD..
#
# Downloading for ticker: 600612.SS
# Saved data for LAO FENG XIANG CO.,LTD..
#
# Downloading for ticker: 600613.SS
# Saved data for Shanghai Shenqi Pharmaceutical Investment Management Co., Ltd..
#
# Downloading for ticker: 600615.SS
# Saved data for Chongqing Shineray Intelligent Manufacturing Technology Co., Ltd..
#
# Downloading for ticker: 600616.SS
# Saved data for SHANGHAI JINFENG WINE COMPANY LIMITED.
#
# Downloading for ticker: 600617.SS
# Saved data for SHANXI GUOXIN ENERGY CORPORATION LIMITED.
#
# Downloading for ticker: 600618.SS
# Saved data for SHANGHAI CHLOR-ALKALI CHEMICAL CO.,LTD..
#
# Downloading for ticker: 600619.SS
# Saved data for SHANGHAI HIGHLY(GROUP) CO.,LTD..
#
# Downloading for ticker: 600620.SS
# Saved data for SHANGHAI TIANCHEN CO.,LTD..
#
# Downloading for ticker: 600621.SS
# Saved data for SHANGHAI CHINAFORTUNE CO., LTD.
#
# Downloading for ticker: 600622.SS
# Saved data for Everbright Jiabao Co.,Ltd.
#
# Downloading for ticker: 600623.SS
# Saved data for SHANGHAI HUAYI GROUP CORPORATION  LTD..
#
# Downloading for ticker: 600626.SS
# Saved data for Shanghai Shenda Co.,Ltd..
#
# Downloading for ticker: 600628.SS
# Saved data for SHANGHAI NEW WORLD CO.,LTD..
#
# Downloading for ticker: 600629.SS
# Saved data for Arcplus Group PLC.
#
# Downloading for ticker: 600630.SS
# Saved data for SHANGHAI DRAGON CORPORATION.
#
# Downloading for ticker: 600633.SS
# Saved data for Zhejiang Daily Digital Culture Group Co.,Ltd..
#
# Downloading for ticker: 600635.SS
# Saved data for Shanghai DaZhong Public Utilities (Group) Co.,Ltd.
#
# Downloading for ticker: 600637.SS
# Saved data for Oriental Pearl Group Co., Ltd..
#
# Downloading for ticker: 600638.SS
# Saved data for SHANGHAI NEW HUANG PU INDUSTRIAL GROUP CO., LTD..
#
# Downloading for ticker: 600639.SS
# Saved data for Shanghai Jinqiao Export Processing Zone Development Co.,Ltd..
#
# Downloading for ticker: 600640.SS
# Saved data for New Guomai Digital Culture Co., Ltd.
#
# Downloading for ticker: 600641.SS
# Saved data for Shanghai Vital Deeptech Co., Ltd..
#
# Downloading for ticker: 600642.SS
# Saved data for SHENERGY COMPANY LIMITED.
#
# Downloading for ticker: 600643.SS
# Saved data for SHANGHAI AJ GROUP CO.,LTD..
#
# Downloading for ticker: 600644.SS
# Saved data for LESHAN ELECTRIC POWER CO.,LTD..
#
# Downloading for ticker: 600645.SS
# Saved data for VCANBIO CELL & GENE ENGINEERING CORP., LTD.
#
# Downloading for ticker: 600648.SS
# Saved data for SHANGHAI WAI GAOQIAO FREE TRADE ZONE DEVELOPMENT CO.,LTD..
#
# Downloading for ticker: 600649.SS
# Saved data for Shanghai chengtou Holding Co., Ltd..
#
# Downloading for ticker: 600650.SS
# Saved data for Shanghai Jin Jiang Online Network Service Co., Ltd..
#
# Downloading for ticker: 600651.SS
# Saved data for Shanghai Feilo Acoustics Co., ltd.
#
# Downloading for ticker: 600653.SS
# Saved data for Liaoning Shenhua Holdings Co.,Ltd..
#
# Downloading for ticker: 600654.SS
# Saved data for China Security Co., Ltd.
#
# Downloading for ticker: 600655.SS
# Saved data for SHANGHAI YUYUAN TOURIST MART（GROUP） CO.,LTD.
#
# Downloading for ticker: 600657.SS
# Saved data for Cinda Real Estate Co.，Ltd..
#
# Downloading for ticker: 600658.SS
# Saved data for Beijing Electronic Zone High-tech Group Co., Ltd..
#
# Downloading for ticker: 600660.SS
# Saved data for FUYAO GLASS INDUSTRY GROUP CO., LTD..
#
# Downloading for ticker: 600661.SS
# Saved data for SHANGHAI XINNANYANG ONLY EDUCATION & TECHNOLOGY CO., LTD.
#
# Downloading for ticker: 600662.SS
# Saved data for Shanghai Foreign Service Holding Group CO.,Ltd..
#
# Downloading for ticker: 600663.SS
# Saved data for Shanghai Lujiazui Finance & Trade Zone Development Co.,Ltd..
#
# Downloading for ticker: 600664.SS
# Saved data for Harbin Pharmaceutical Group CO.,LTD..
#
# Downloading for ticker: 600665.SS
# Saved data for Tande CO.,LTD..
#
# Downloading for ticker: 600666.SS
# Saved data for AURORA OPTOELECTRONICS CO.,LTD.
#
# Downloading for ticker: 600667.SS
# Saved data for WUXI TAIJI INDUSTRY COMPANY LIMITED..
#
# Downloading for ticker: 600668.SS
# Saved data for ZHEJIANG JIANFENG GROUP CO.,LTD.
#
# Downloading for ticker: 600671.SS
# Saved data for HANGZHOU TIAN-MU-SHAN PHARMACEUTICAL ENTERPRISE CO.,LTD.
#
# Downloading for ticker: 600673.SS
# Saved data for GUANGDONG HEC TECHNOLOGY HOLDING CO., LTD.
#
# Downloading for ticker: 600674.SS
# Saved data for SICHUAN CHUANTOU ENERGY CO.,LTD..
#
# Downloading for ticker: 600675.SS
# Saved data for CHINA ENTERPRISE COMPANY LIMITED.
#
# Downloading for ticker: 600676.SS
# Saved data for SHANGHAI JIAO YUN  GROUP CO., LTD..
#
# Downloading for ticker: 600678.SS
# Saved data for SICHUAN GOLDEN SUMMIT (GROUP) JOINT-STOCK CO., LTD..
#
# Downloading for ticker: 600679.SS
# Saved data for ShangHai Phoenix Enterprise (Group) CO., LTD..
#
# Downloading for ticker: 600681.SS
# Saved data for BESTSUN ENERGY  CO., LTD..
#
# Downloading for ticker: 600682.SS
# Saved data for NANJING XINJIEKOU DEPARTMENT STORE CO.,LTD.
#
# Downloading for ticker: 600683.SS
# Saved data for METRO LAND CORPORATION LTD.
#
# Downloading for ticker: 600684.SS
# Saved data for GUANGZHOU PEARL RIVER DEVELOPMENT GROUP CO., LTD..
#
# Downloading for ticker: 600685.SS
# Saved data for CSSC OFFSHORE & MARINE ENGINEERING (GROUP) COMPANY LIMITED.
#
# Downloading for ticker: 600686.SS
# Saved data for XIAMEN KING LONG MOTOR GROUP CO.,TLD..
#
# Downloading for ticker: 600688.SS
# Saved data for SINOPEC SHANGHAI PETROCHEMICAL CO.,LTD.
#
# Downloading for ticker: 600689.SS
# Saved data for SHANGHAI SANMAO ENTERPRISE (GROUP) CO.，LTD..
#
# Downloading for ticker: 600690.SS
# Saved data for Haier Smart Home Co., Ltd..
#
# Downloading for ticker: 600691.SS
# Saved data for Shanxi Lu'an Chemical Technology Co.,Ltd..
#
# Downloading for ticker: 600692.SS
# Saved data for SHANG HAI YA TONG CO.,LTD..
#
# Downloading for ticker: 600693.SS
# Saved data for FUJIAN DONGBAI GROUP CO.,LTD..
#
# Downloading for ticker: 600694.SS
# Saved data for DASHANG CO.，LTD..
#
# Downloading for ticker: 600697.SS
# Saved data for CHANG CHUN EURASIA GROUP CO., LTD..
#
# Downloading for ticker: 600698.SS
# Saved data for HUNAN TYEN MACHINERY CO., LTD.
#
# Downloading for ticker: 600699.SS
# Saved data for NINGBO JOYSON ELECTRONIC CORP..
#
# Downloading for ticker: 600702.SS
# Saved data for Shede Spirits Co., Ltd..
#
# Downloading for ticker: 600703.SS
# Saved data for SAN'AN OPTOELECTRONICS CO.,LTD.
#
# Downloading for ticker: 600704.SS
# Saved data for Wuchan Zhongda Group Co., Ltd..
#
# Downloading for ticker: 600706.SS
# Saved data for XI’AN QUJIANG CULTURAL TOURISM CO.,LTD..
#
# Downloading for ticker: 600707.SS
# Saved data for CAIHONG DISPLAY DEVICES CO.,LTD..
#
# Downloading for ticker: 600708.SS
# Saved data for BRIGHT REAL ESTATE GROUP CO.,LIMITED.
#
# Downloading for ticker: 600710.SS
# Saved data for SUMEC CORPORATION LIMITED.
#
# Downloading for ticker: 600711.SS
# Saved data for CHENGTUN MINING GROUP CO.,LTD.
#
# Downloading for ticker: 600712.SS
# Saved data for NANNING DEPARTMENT STORE CO.,LTD..
#
# Downloading for ticker: 600713.SS
# Saved data for Nanjing Pharmaceutical Group Company Limited.
#
# Downloading for ticker: 600714.SS
# Saved data for Qinghai Jinrun Mineral Development Co., Ltd.
#
# Downloading for ticker: 600715.SS
# Saved data for CULTURAL INVESTMENT HOLDINGS CO.，LTD..
#
# Downloading for ticker: 600716.SS
# Saved data for JIANGSU PHOENIX PROPERTY INVESTMENT COMPANY LIMITED.
#
# Downloading for ticker: 600717.SS
# Saved data for TIANJIN PORT HOLDINGS CO.,LTD..
#
# Downloading for ticker: 600718.SS
# Saved data for Neusoft Corporation.
#
# Downloading for ticker: 600719.SS
# Saved data for DALIAN THERMAL POWER CO.,LTD..
#
# Downloading for ticker: 600720.SS
# Saved data for CCCC Design & Consulting Group Co., Ltd..
#
# Downloading for ticker: 600721.SS
# Saved data for XINJIANG BAI HUA CUN PHARMA TECH CO.,LTD.
#
# Downloading for ticker: 600722.SS
# Saved data for HEBEI JINNIU CHEMICAL INDUSTRIAL CO., LTD.
#
# Downloading for ticker: 600724.SS
# Saved data for NINGBO FUDA COMPANY LIMITED.
#
# Downloading for ticker: 600725.SS
# Saved data for YUNNAN YUNWEI COMPANY LIMITED.
#
# Downloading for ticker: 600726.SS
# Saved data for Huadian Energy Company Limited.
#
# Downloading for ticker: 600727.SS
# Saved data for SHANDONG LUBEI CHEMICAL CO.,LTD..
#
# Downloading for ticker: 600728.SS
# Saved data for PCI TECHNOLOGY GROUP CO.,LTD..
#
# Downloading for ticker: 600729.SS
# Saved data for CHONGQING DEPARTMENT STORE CO.,LTD..
#
# Downloading for ticker: 600730.SS
# Saved data for CHINA HI-TECH GROUP CO.,LTD..
#
# Downloading for ticker: 600731.SS
# Saved data for HUNAN HAILI CHEMICAL INDUSTRY CO.,LTD..
#
# Downloading for ticker: 600732.SS
# Saved data for Shanghai Aiko Solar Energy Co., Ltd..
#
# Downloading for ticker: 600733.SS
# Saved data for BluePark New Energy Technology Co,.Ltd.
#
# Downloading for ticker: 600734.SS
# Saved data for Fujian Start Group Co. Ltd.
#
# Downloading for ticker: 600736.SS
# Saved data for SUZHOU NEW DISTRICT HI-TECH INDUSTRIAL CO.,LTD.
#
# Downloading for ticker: 600737.SS
# Saved data for COFCO  SUGAR HOLDING  CO.,LTD..
#
# Downloading for ticker: 600738.SS
# Saved data for LANZHOU LISHANG GUOCHAO INDUSTRIAL GROUP CO.,LTD.
#
# Downloading for ticker: 600739.SS
# Saved data for LIAONING CHENGDA CO.,LTD..
#
# Downloading for ticker: 600740.SS
# Saved data for SHAN XI COKING CO.,LTD.
#
# Downloading for ticker: 600741.SS
# Saved data for HUAYU Automotive Systems Company Limited.
#
# Downloading for ticker: 600742.SS
# Saved data for Changchun FAWAY Group Automobile Components Co.,Ltd.
#
# Downloading for ticker: 600743.SS
# Saved data for Beijing Huayuan Xinhang Holding Co.,Ltd..
#
# Downloading for ticker: 600744.SS
# Saved data for DATANG HUAYIN ELECTRIC POWER CO.,LTD..
#
# Downloading for ticker: 600745.SS
# Saved data for Wingtech Technology Co.,Ltd..
#
# Downloading for ticker: 600746.SS
# Saved data for JIANGSU SOPO CHEMICAL CO.LTD..
#
# Downloading for ticker: 600748.SS
# Saved data for SHANGHAI INDUSTRIAL DEVELOPMENT CO.,LTD..
#
# Downloading for ticker: 600749.SS
# Saved data for XIZANG TOURISM CO.,LTD.
#
# Downloading for ticker: 600750.SS
# Saved data for China Resources Jiangzhong Pharmaceutical Co.,Ltd.
#
# Downloading for ticker: 600751.SS
# Saved data for HNA Technology Co.,Ltd..
#
# Downloading for ticker: 600754.SS
# Saved data for Shanghai Jin Jiang International Hotels Co.,Ltd..
#
# Downloading for ticker: 600755.SS
# Saved data for XIAMEN ITG GROUP CORP., LTD..
#
# Downloading for ticker: 600756.SS
# Saved data for Inspur software  Co.,Ltd..
#
# Downloading for ticker: 600757.SS
# Saved data for Changjiang Publishing & Media Co.,Ltd.
#
# Downloading for ticker: 600758.SS
# Saved data for LIAONING ENERGY INDUSTRY CO.,LTD.
#
# Downloading for ticker: 600759.SS
# Saved data for Geo-Jade Petroleum Corporation.
#
# Downloading for ticker: 600760.SS
# Saved data for AVIC SHENYANG AIRCRAFT COMPANY LIMITED.
#
# Downloading for ticker: 600761.SS
# Saved data for ANHUI HELI CO.,LTD..
#
# Downloading for ticker: 600763.SS
# Saved data for TOPCHOICE MEDICAL CO.INC.
#
# Downloading for ticker: 600764.SS
# Saved data for China Marine Information Electronics Company Limited.
#
# Downloading for ticker: 600765.SS
# Saved data for AVIC HEAVY MACHINERY CO.,LTD..
#
# Downloading for ticker: 600768.SS
# Saved data for NINGBO FUBANG JINGYE GROUP Co,.LTD.
#
# Downloading for ticker: 600769.SS
# Saved data for WUHAN XIANGLONG POWER INDUSTRY CO,LTD..
#
# Downloading for ticker: 600770.SS
# Saved data for Jiangsu Zongyi Co.,LTD.
#
# Downloading for ticker: 600771.SS
# Saved data for GuangYuYuan Chinese Herbal Medicine Co., Ltd..
#
# Downloading for ticker: 600773.SS
# Saved data for Tibet Urban Development and Investment Co.,LTD.
#
# Downloading for ticker: 600774.SS
# Saved data for HANSHANG GROUP CO.,LTD..
#
# Downloading for ticker: 600775.SS
# Saved data for NANJING PANDA ELECTRONICS COMPANY LIMITED.
#
# Downloading for ticker: 600776.SS
# Saved data for EASTERN COMMUNICATIONS CO.,LTD..
#
# Downloading for ticker: 600778.SS
# Saved data for XINJIANG YOUHAO (GROUP) CO.,LTD.
#
# Downloading for ticker: 600779.SS
# Saved data for SICHUAN SWELLFUN CO.,LTD.
#
# Downloading for ticker: 600780.SS
# Saved data for TOP ENERGY COMPANY LTD.SHANXI.
#
# Downloading for ticker: 600782.SS
# Saved data for Xinyu Iron ＆ Steel Co.,Ltd.
#
# Downloading for ticker: 600783.SS
# Saved data for Luxin Venture Capital Group Co., Ltd..
#
# Downloading for ticker: 600784.SS
# Saved data for LUYIN INVESTMENT GROUP CO.,LTD..
#
# Downloading for ticker: 600785.SS
# Saved data for YINCHUAN XINHUA COMMERCIAL (GROUP) CO.,LTD..
#
# Downloading for ticker: 600787.SS
# Saved data for CMST Development Co.,Ltd..
#
# Downloading for ticker: 600789.SS
# Saved data for SHANDONG LUKANG PHARMACEUTICAL CO.,LTD..
#
# Downloading for ticker: 600790.SS
# Saved data for ZheJiang China Light&Textile Industrial City Group Co.,Ltd..
#
# Downloading for ticker: 600791.SS
# Saved data for BEH-PROPERTY CO., LTD.
#
# Downloading for ticker: 600792.SS
# Saved data for Yunnan Coal & Energy Co.,Ltd..
#
# Downloading for ticker: 600793.SS
# Saved data for YibinpaperindustryCO.,LTD.
#
# Downloading for ticker: 600794.SS
# Saved data for ZHANGJIAGANG FREETRADE SCIENCE & TECHNOLOGY GROUP CO., LTD..
#
# Downloading for ticker: 600795.SS
# Saved data for GD POWER DEVELOPMENT CO., LTD.
#
# Downloading for ticker: 600796.SS
# Saved data for ZHEJIANG QIANJIANG BIOCHEMICAL COMPANY LIMITED.
#
# Downloading for ticker: 600797.SS
# Saved data for INSIGMA TECHNOLOGY CO.,LTD..
#
# Downloading for ticker: 600798.SS
# Saved data for NINGBO MARINE COMPANY LIMITED..
#
# Downloading for ticker: 600800.SS
# Saved data for TIAN JIN BOHAI CHEMICAL CO.,LTD..
#
# Downloading for ticker: 600801.SS
# Saved data for HUAXIN BUILDING MATERIALS GROUP CO., LTD..
#
# Downloading for ticker: 600802.SS
# Saved data for FUJIAN CEMENT INC..
#
# Downloading for ticker: 600803.SS
# Saved data for ENN Natural Gas Co., Ltd..
#
# Downloading for ticker: 600805.SS
# Saved data for Jiangsu Yueda Investment Co.Ltd..
#
# Downloading for ticker: 600807.SS
# Saved data for Jinan High-tech Development Co., Ltd..
#
# Downloading for ticker: 600808.SS
# 1 Failed download:
# ['600808.SS']: SSLError('Failed to perform, curl: (35) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Downloading for ticker: 600809.SS
# Saved data for SHANXI XINGHUACUN FEN WINE FACTORY  CO.,LTD.

# %% [markdown]
# Note: The code above takes around 40-50 minutes to completely run.

# %% [markdown]
# ## Discarded Code

# %% [markdown]
# This code was disregarded because the files it generated were too big to be committed on the GitHub.

# %%
# declare start and end dates
start_date = '2000-01-01'
end_date = '2026-01-01'

def download_stocks_in_batches(tickers, batch_size=5, delay=1, verbose=False):
    """
    Download stock data in batches to avoid rate limiting
    """
    all_data = {}
    
    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i + batch_size]
        if verbose:
            print(f"Downloading batch {i//batch_size + 1}: {batch}")
        
        try:
            # Download the batch
            batch_data = yf.download(
                batch,
                start=start_date,
                end=end_date,
                progress=False
            )
            
            # Extract closing prices for this batch
            if not batch_data.empty and 'Close' in batch_data.columns:
                closes = batch_data['Close']
                if isinstance(closes, pd.Series):
                    all_data[batch[0]] = closes
                else:
                    for ticker in closes.columns:
                        all_data[ticker] = closes[ticker]
                if verbose:
                    print(f"Successfully downloaded {len(batch)} stocks")
            else:
                print(f"No data returned for batch: {batch}")
            
        except Exception as e:
            print(f"Error downloading batch {batch}: {e}")
        
        # Add delay to avoid rate limiting
        if i + batch_size < len(tickers):
            if verbose:
                print(f"Waiting {delay} seconds before next batch...")
            time.sleep(delay)
    
    if all_data:
        return pd.DataFrame(all_data)
    else:
        return pd.DataFrame()

# %%
# # Download the closing prices
# closing_df = download_stocks_in_batches(
#     tickers_list, 
#     batch_size=5, 
#     delay=5
# )

# # removing unnecessary columns and rows
# closing_df.dropna(how='all', axis=1, inplace=True)
# closing_df.dropna(how='all', axis=0, inplace=True)

# # # save to pkl
# # if not closing_df.empty:
# #     closing_df.to_pickle('SSE companies closing prices.pkl')

# # cut into parts
# closing_df1 = closing_df.iloc[:, :int(np.floor(len(closing_df) / 2))]
# closing_df2 = closing_df.iloc[:, int(np.floor(len(closing_df) / 2)):]

# # save as pkl files
# if not closing_df1.empty and closing_df2.empty:
#     closing_df1.to_pickle('data/01 SSE companies closing prices.pkl')
#     closing_df2.to_pickle('data/02 SSE companies closing prices.pkl')

# %% [markdown]
# Note: The code above takes around 30-45 minutes to completely run.
